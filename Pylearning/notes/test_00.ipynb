# %% [markdown]
# **多行语句**
#
# Python 通常是一行写完一条语句，但如果语句很长，我们可以使用反斜杠 \ 来实现多行语句，例如：
#
# ```python
# total = item_one + \
#         item_two + \
#         item_three
# ```
#
# 在 [], {}, 或 () 中的多行语句，不需要使用反斜杠 \，例如：
#
# ```python
# total = ['item_one', 'item_two', 'item_three',
#         'item_four', 'item_five']
# ```
#
# **字符串**
#
# 反斜杠可以用来转义，使用 r 可以让反斜杠不发生转义。 如 `r"this is a line with \n"` 则 \n 会显示，并不是换行。
#
#
# 字符串可以截取`变量名[头角标： 尾角标： 步长]`
#
# 比如`str[1: 5: 2]`就是从第二个开始，到第六个为止，且步长为二的字符。
#
# 这里当然会有一些我永远都不可能记得住的问题，比如开头包不包含，结尾包不包含，但我不在乎，这不是重点。
#
# 注意，在字符串之前加`r`可以将反斜杠转义
#
# 注意，python输出的时候默认换行，如果你不想换行，可以这样
# `print(x, end = "")`

# %%
input("\n\n按下回车后退出")
# Out:
# ''

# %% [markdown]
# **数据类型**
#
# 介绍两个函数
# `isinstance`和`type`
# 前者可以判断某个对象的类型，输出布尔值；后者可以输出对象的类型（需要注意的是，前者会认为子类也是一种父类的类型）
#
# **截取，索引**
#
# ![image.png](attachment:image.png)
#
# 与 C 字符串不同的是，Python 字符串不能被改变。向一个索引位置赋值，比如 word[0] = 'm' 会导致错误。
# （也许从这里可以看出来，python有时候并不能碰到底层的一些东西）
#
# **列表**
#
# ```python
# print (list[1:3])       # 从第二个开始输出到第三个元素
# print (list[2:])        # 输出从第三个元素开始的所有元素
# print (tinylist * 2)    # 输出两次列表
# ```
#
# 列表中的元素可以改变
#
# 其实，字符串，列表，元组都属于**序列(sequence)**，区别在于列表是可变的，而元组和字符串不可变（可以把字符串看作元素都是“字符”的元组）。还需要注意元组有空元组和一个元素的元组，语法有所特殊
#
# ---
#
# **集合**
#
# 集合无序，可变，用大括号表示，可以进行你所知道的那些集合操作。
#
# **注意：**创建一个空集合必须用 `set()` 而不是 `{ }`，因为 `{ }` 是用来创建一个空字典。
#
# **字典**
#
# 字典是一种**映射**类型，是键和值的集合，同一个字典中，键必须唯一
#
# **数据类型的转换**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **python解释器**
#
# python有两种编程的方法：交互式编程，脚本式编程

# %% [markdown]
# **列表**
#
# 列表的方法：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **元组**
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# **字典**
#
# 对字典的值的访问：
#
# 可以把相应的键放在方括号中
#
# ```python
# print(字典名['键名'])
#
# ```
#
# 字典的键：
# ![image-4.png](attachment:image-4.png)
#
# 关于字典的函数
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
#
#
# **集合**
#
# 添加元素：
#
# s.add()
#
# s.update()
#
# 这两种方法的区别是，前者只能将元素添加到集合中去，但是后者的参数可以是列表，元组，或者元素
#
# 移除元素：
#
# s.remove()
#
# s.discard()
#
# s.pop()
#
# 区别：第一个，如果集合中没有输入的参数，会发生报错，第二个不会，而第三个删除的元素是随机的
#
#
# len(s)
#
# s.clear()
#
# x in s
#
# 顾名思义
# ![image-7.png](attachment:image-7.png)
